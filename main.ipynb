# %% [markdown]
# # **Gender Recongition using Voice and Speech Analysis**

# %% [markdown]
# #### **Importing Libraries**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from pandas.tools.plotting import radviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 7
#       5 from sklearn.manifold import TSNE
#       6 from sklearn.preprocessing import StandardScaler
# ----> 7 from pandas.tools.plotting import radviz
#
# ModuleNotFoundError: No module named 'pandas.tools'

# %% [markdown]
# #### **Loading Data**

# %%
voice_data = pd.read_csv(r'C:\Users\Paridhi\Dropbox\PC\Documents\Projects\Gender Recognition using Voice and Speech Analysis\Data\voice.csv')
voice_data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462  \
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702  \
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %% [markdown]
# #### **Checking for null values**

# %%
voice_data.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %% [markdown]
# #### **Describing the Data**

# %%
voice_data.shape
# Out:
# (3168, 21)

# %%
voice_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
voice_data.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000  \
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000  \
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
print("Total number of data samples: {}".format(voice_data.shape[0]))
print("Total number of Male data samples: {}".format(voice_data[voice_data.label == 'male'].value_counts().sum()))
print("Total number of Female data samples: {}".format(voice_data[voice_data.label == 'female'].value_counts().sum()))
# Out:
# Total number of data samples: 3168
# Total number of Male data samples: 1584
# Total number of Female data samples: 1584

# %% [markdown]
# ### Visualizations for Analysis
#
# #### **I. Correlation Plots**

# %%
cmap = plt.cm.magma
plt.figure(figsize=(18, 16))
plt.title('Pearson Correlation of Features', y=1.02, size=18)
sns.heatmap(voice_data.iloc[:, :-1].astype(float).corr(), linewidth = 0.5, vmax = 1, square = True, cmap=cmap, linecolor='white', annot=True)
# Out:
# <Axes: title={'center': 'Pearson Correlation of Features'}>

# %% [markdown]
# #### **II. Implementing TNSE**

# %%
X_data = voice_data.iloc[:, :-1]
Y_data = voice_data['label']
Y_data = Y_data.replace({'male':1, 'female':0})

# %%
X_scale = StandardScaler().fit_transform(X_data)
tsne = TSNE(n_components=2, init='pca', random_state=0)
X_t = tsne.fit_transform(X_scale)

# %%
plt.figure()
plt.scatter(X_t[np.where(Y_data == 0), 0], X_t[np.where(Y_data == 0), 1], marker='x', color='yellow', linewidth=1.2, alpha = 0.5, label='Male')
plt.scatter(X_t[np.where(Y_data == 1), 0], X_t[np.where(Y_data == 1), 1], marker='v', color='pink', linewidth=1.2, alpha = 0.5, label='Male')

plt.xlabel('Dimension I')
plt.ylabel('Dimension II')
plt.title('T-SNE')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### **III. Scatter plots**

# %%
sns.FacetGrid(voice_data, hue='label').map(plt.scatter, "meanfun", "meanfreq").add_legend()
plt.show()

# %% [markdown]
# #### **IV. Boxplot**

# %%
sns.boxplot(x='label', y="meanfun", data=voice_data)
plt.show()

# %% [markdown]
# #### **V. Pair Plots**

# %%
sns.pairplot(voice_data[['meanfreq', 'Q25', 'Q75', 'skew', 'centroid', 'label']], hue='label', size=2)
# Out:
# c:\Users\Paridhi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### **VI. KDE or Density Plots**
# To study the distribution of each feature of the males and females

# %%
sns.FacetGrid(voice_data, hue="label").map(sns.kdeplot, "meanfun").add_legend()
plt.show()

# %% [markdown]
# #### **VII. Radviz Circle**
# To compare each and every feature of the dataset.

# %%
radviz(voice_data, "label")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 radviz(voice_data, "label")
#       2 plt.show()
#
# NameError: name 'radviz' is not defined
